# %% [markdown]
# ### 🧹 Data Cleaning Insight
# Cleaned and standardized order data, calculated new business metrics (Discount, Sale Price, Profit),
# and prepared the dataset for analysis by handling missing values and formatting dates.

# %%
import pandas as pd

# %%
import pandas as pd
df=pd.read_csv('orders.csv',na_values=['Not Available','unknown'])

# %%
df.head(20)
# Out:
#     Order Id  Order Date       Ship Mode      Segment        Country  \
# 0          1  2023-03-01    Second Class     Consumer  United States
# 1          2  2023-08-15    Second Class     Consumer  United States
# 2          3  2023-01-10    Second Class    Corporate  United States
# 3          4  2022-06-18  Standard Class     Consumer  United States
# 4          5  2022-07-13  Standard Class     Consumer  United States
# 5          6  2022-03-13             NaN     Consumer  United States
# 6          7  2022-12-28  Standard Class     Consumer  United States
# 7          8  2022-01-25  Standard Class     Consumer  United States
# 8          9  2023-03-23             NaN     Consumer  United States
# 9         10  2023-05-16  Standard Class     Consumer  United States
# 10        11  2023-03-31             NaN     Consumer  United States
# 11        12  2023-12-25             NaN     Consumer  United States
# 12        13  2022-02-11  Standard Class     Consumer  United States
# ...

# %%
df.isnull().sum()
# Out:
# Order Id            0
# Order Date          0
# Ship Mode           6
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code         0
# Region              0
# Category            0
# Sub Category        0
# Product Id          0
# cost price          0
# List Price          0
# Quantity            0
# Discount Percent    0
# dtype: int64

# %%
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")

# %%
df.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
df[df['ship_mode'].isnull()]
# Out:
#      order_id  order_date ship_mode      segment        country         city  \
# 5           6  2022-03-13       NaN     Consumer  United States  Los Angeles
# 8           9  2023-03-23       NaN     Consumer  United States  Los Angeles
# 10         11  2023-03-31       NaN     Consumer  United States  Los Angeles
# 11         12  2023-12-25       NaN     Consumer  United States  Los Angeles
# 14         15  2023-11-09       NaN  Home Office  United States   Fort Worth
# 118       119  2023-07-19       NaN    Corporate  United States      Bristol
#
#           state  postal_code   region         category sub_category  \
# 5    California        90032     West        Furniture  Furnishings
# 8    California        90032     West  Office Supplies      Binders
# 10   California        90032     West        Furniture       Tables
# 11   California        90032     West       Technology       Phones
# 14        Texas        76106  Central  Office Supplies   Appliances
# ...

# %%
df['ship_mode'] = df['ship_mode'].fillna(df['ship_mode'].mode()[0])

# %%
df.isnull().sum()
# Out:
# order_id            0
# order_date          0
# ship_mode           0
# segment             0
# country             0
# city                0
# state               0
# postal_code         0
# region              0
# category            0
# sub_category        0
# product_id          0
# cost_price          0
# list_price          0
# quantity            0
# discount_percent    0
# dtype: int64

# %%
# Discount 
df['Discount']=df['list_price']*df['discount_percent']*.01

# %%
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
# sale Price
df['Sale_Price']=df['list_price']-df['Discount']

# %%
# profit 
df['Profit']=df['Sale_Price']-df['cost_price']

# %%
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
# convert order_date object to datetime format
df['order_date']=pd.to_datetime(df['order_date'],format='%Y-%m-%d')

# %%
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
# drop the columns
df.drop(columns=['cost_price','list_price','discount_percent'],inplace=True)

# %%
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
# !pip install pymysql sqlalchemy pandas

# %%
import pandas as pd
from sqlalchemy import create_engine

# Replace with your actual MySQL credentials
username = 'root'
password = 'admin123'
host = 'localhost'
port = 3306
database = 'Orders'

# SQLAlchemy connection string using variables
engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# %%
df.head()
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  Discount  Sale_Price  Profit
# 0    Bookcases  FUR-BO-10001798         2       5.2       254.8    14.8
# ...

# %%
df.to_sql('orders', con=engine, if_exists='replace', index=False)
# Out:
# 9994

# %%
df.head()
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  Discount  Sale_Price  Profit
# 0    Bookcases  FUR-BO-10001798         2       5.2       254.8    14.8
# ...

# %%
df.to_csv("Orders_data.csv", index=False)

# %%
df.head()
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  Discount  Sale_Price  Profit
# 0    Bookcases  FUR-BO-10001798         2       5.2       254.8    14.8
# ...

# %%
df['reveune']=df['Sale_Price']*df['quantity']

# %%
print(df['reveune'])
# Out:
# 0        509.6
# 1       2124.3
# 2         19.0
# 3       4704.0
# 4         38.0
#          ...
# 9989      86.4
# 9990     172.8
# 9991     509.6
# 9992     116.4
# 9993     465.6
# Name: reveune, Length: 9994, dtype: float64

# %%
df.head()
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  Discount  Sale_Price  Profit  \
# 0    Bookcases  FUR-BO-10001798         2       5.2       254.8    14.8
# ...

# %%
total_revenue = df['reveune'].sum()

# Total Unique Orders
unique_orders = df['order_id'].nunique()

# AOV
aov = round(total_revenue / unique_orders, 2)

print("Python AOV:", aov)
# Out:
# Python AOV: 1108.6

# %%
df.head()
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  Discount  Sale_Price  Profit  \
# 0    Bookcases  FUR-BO-10001798         2       5.2       254.8    14.8
# ...

# %%
filter_rows=df[df['order_id']=='4390']

# %%
filter_rows
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_mode, segment, country, city, state, postal_code, region, category, sub_category, product_id, quantity, Discount, Sale_Price, Profit, reveune]
# Index: []

# %%
print(df['order_id'].unique())
# Out:
# [   1    2    3 ... 9992 9993 9994]

# %%
print(df.dtypes)
# Out:
# order_id                 int64
# order_date      datetime64[ns]
# ship_mode               object
# segment                 object
# country                 object
# city                    object
# state                   object
# postal_code              int64
# region                  object
# category                object
# sub_category            object
# product_id              object
# quantity                 int64
# Discount               float64
# Sale_Price             float64
# Profit                 float64
# reveune                float64
# dtype: object

# %%
filter_rows = df[(df["order_id"] == 4390) & (df["product_id"]=="FUR-BO-10003159") & (df['postal_code']==10035)]

# %%
filter_rows
# Out:
#       order_id order_date    ship_mode   segment        country  \
# 4389      4390 2023-11-28  First Class  Consumer  United States
#
#                city     state  postal_code region   category sub_category  \
# 4389  New York City  New York        10035   East  Furniture    Bookcases
#
#            product_id  quantity  Discount  Sale_Price  Profit  reveune
# 4389  FUR-BO-10003159         2       9.0       171.0     1.0    342.0

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'quantity', 'Discount', 'Sale_Price', 'Profit',
#        'reveune'],
#       dtype='object')

# %%
df['order_id']==8918
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Name: order_id, Length: 9994, dtype: bool

# %%
df['order_id'] = df['order_id'].astype(str).str.strip()
df[df['order_id'] == '8918']
# Out:
#      order_id order_date       ship_mode    segment        country    city  \
# 8917     8918 2022-11-15  Standard Class  Corporate  United States  Austin
#
#       state  postal_code   region         category sub_category  \
# 8917  Texas        78745  Central  Office Supplies        Paper
#
#            product_id  quantity  Discount  Sale_Price  Profit  reveune
# 8917  OFF-PA-10004327         2       4.0        76.0    -4.0    152.0

# %%
df.dtypes
# Out:
# order_id                object
# order_date      datetime64[ns]
# ship_mode               object
# segment                 object
# country                 object
# city                    object
# state                   object
# postal_code              int64
# region                  object
# category                object
# sub_category            object
# product_id              object
# quantity                 int64
# Discount               float64
# Sale_Price             float64
# Profit                 float64
# reveune                float64
# dtype: object

# %%
df[df['order_id'] == '8918']
# Out:
#      order_id order_date       ship_mode    segment        country    city  \
# 8917     8918 2022-11-15  Standard Class  Corporate  United States  Austin
#
#       state  postal_code   region         category sub_category  \
# 8917  Texas        78745  Central  Office Supplies        Paper
#
#            product_id  quantity  Discount  Sale_Price  Profit  reveune
# 8917  OFF-PA-10004327         2       4.0        76.0    -4.0    152.0

# %%
df[df['order_id'] == '3']
# Out:
#   order_id order_date     ship_mode    segment        country         city  \
# 2        3 2023-01-10  Second Class  Corporate  United States  Los Angeles
#
#         state  postal_code region         category sub_category  \
# 2  California        90036   West  Office Supplies       Labels
#
#         product_id  quantity  Discount  Sale_Price  Profit  reveune
# 2  OFF-LA-10000240         2       0.5         9.5    -0.5     19.0

# %%
df.dtypes
# Out:
# order_id                object
# order_date      datetime64[ns]
# ship_mode               object
# segment                 object
# country                 object
# city                    object
# state                   object
# postal_code              int64
# region                  object
# category                object
# sub_category            object
# product_id              object
# quantity                 int64
# Discount               float64
# Sale_Price             float64
# Profit                 float64
# reveune                float64
# dtype: object
